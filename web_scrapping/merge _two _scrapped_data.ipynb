# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv('Data.csv')
df2 = pd.read_csv('mcq_data.csv')

# %%
df1
# Out:
#                                               Question  \
# 0                        1- ما أول ما نزل من التوراة ؟
# 1    2ـ ما أول هدية أهديت إلى الرسول صلى الله عليه ...
# 2    3ـ من أول من قُتل من المشركين في غزوة بدر الكب...
# 3                      4ـ من هي أول امرأة بكر هاجرت ؟
# 4                                  5ـ من أول من صام ؟
# ..                                                 ...
# 913                       996ـ ما اسم الشهيد المصلوب ؟
# 914  997ـ ما هي أبرز الأسماء التي وردت في القرآن ال...
# 915           998ـ كم من السنين مكث أهل الكهف نياماً ؟
# 916  999ـ من هم الداخلون الأوائل إلى الجنة في الإسل...
# 917        1000ـ ما هي الآية التي نزلت في جوف الكعبة ؟
#
#                                                 Answer
# 0                             بسم الله الرحمن الرحيم .
# 1         قصعة خبزاً وسمناً ولبناً وهي هدية من زيد ...
# 2         الأسود بن عبد الأسد المخزومي والذي قتله ح...
# 3                      أم كلثوم بنت عقبة بن أبي معيط .
# ...

# %%
df2
# Out:
#                                              Questions               Answer
# 0                            كم عدد سور القرآن الكريم؟                  114
# 1              في أي الأيام خلق سيدنا آدم عليه السلام؟           يوم الجمعة
# 2              كم عدد السنوات التي نام فيها أهل الكهف؟            309 سنوات
# 3                       اسم أول صحابي قرأ القرآن جهرة؟    عبد الله بن مسعود
# 4                    من هي أخر زوجات النبي التي توفيت؟       السيدة أم سلمة
# ..                                                 ...                  ...
# 735  ما حكم المد في الآية الكريمة (وَمَا أَدْرَاكَ ...             مد منفصل
# 736  ما حكم التنوين في قوله تعالى (وَجَنَّاتٍ أَلْف...                إظهار
# 737     معنى الإظهار الحلقي اصطلاحا هو البيان والوضوح؟                  خطأ
# 738                                 ما هو سبب الإظهار؟              التباعد
# 739                   ما حكم النون المشددة في كلمة عم؟   غنة مقدارها حركتين
#
# [740 rows x 2 columns]

# %%
df = pd.merge(df1, df2, how='outer')
df
# Out:
#                                                Question  \
# 0                         1- ما أول ما نزل من التوراة ؟
# 1     2ـ ما أول هدية أهديت إلى الرسول صلى الله عليه ...
# 2     3ـ من أول من قُتل من المشركين في غزوة بدر الكب...
# 3                       4ـ من هي أول امرأة بكر هاجرت ؟
# 4                                   5ـ من أول من صام ؟
# ...                                                 ...
# 1653  ما حكم المد في الآية الكريمة (وَمَا أَدْرَاكَ ...
# 1654  ما حكم التنوين في قوله تعالى (وَجَنَّاتٍ أَلْف...
# 1655     معنى الإظهار الحلقي اصطلاحا هو البيان والوضوح؟
# 1656                                 ما هو سبب الإظهار؟
# 1657                   ما حكم النون المشددة في كلمة عم؟
#
#                                                  Answer
# 0                              بسم الله الرحمن الرحيم .
# 1          قصعة خبزاً وسمناً ولبناً وهي هدية من زيد ...
# 2          الأسود بن عبد الأسد المخزومي والذي قتله ح...
# 3                       أم كلثوم بنت عقبة بن أبي معيط .
# ...

# %%
len(df1) + len(df2)
# Out:
# 1658

# %%
df.to_csv('NLP_DATA.csv', index=False)

# %%
df = pd.read_csv('NLP_DATA.csv')

# %%
df
# Out:
#                                                Question  \
# 0                         1- ما أول ما نزل من التوراة ؟
# 1     2ـ ما أول هدية أهديت إلى الرسول صلى الله عليه ...
# 2     3ـ من أول من قُتل من المشركين في غزوة بدر الكب...
# 3                       4ـ من هي أول امرأة بكر هاجرت ؟
# 4                                   5ـ من أول من صام ؟
# ...                                                 ...
# 1653  ما حكم المد في الآية الكريمة (وَمَا أَدْرَاكَ ...
# 1654  ما حكم التنوين في قوله تعالى (وَجَنَّاتٍ أَلْف...
# 1655     معنى الإظهار الحلقي اصطلاحا هو البيان والوضوح؟
# 1656                                 ما هو سبب الإظهار؟
# 1657                   ما حكم النون المشددة في كلمة عم؟
#
#                                                  Answer
# 0                              بسم الله الرحمن الرحيم .
# 1          قصعة خبزاً وسمناً ولبناً وهي هدية من زيد ...
# 2          الأسود بن عبد الأسد المخزومي والذي قتله ح...
# 3                       أم كلثوم بنت عقبة بن أبي معيط .
# ...
